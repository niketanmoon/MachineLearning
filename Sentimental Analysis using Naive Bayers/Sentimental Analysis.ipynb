# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
filename = "imdb_master.csv"
import chardet
with open(filename, "rb") as f:
    result = chardet.detect(f.read(100000))

result
# Out:
# {'encoding': 'CP949', 'confidence': 0.99, 'language': 'Korean'}

# %%
full_dataset = pd.read_csv(filename, encoding="ISO-8859-1")

# %%
full_dataset
# Out:
#        Unnamed: 0   type                                             review  \
# 0               0   test  Once again Mr. Costner has dragged out a movie...
# 1               1   test  This is an example of why the majority of acti...
# 2               2   test  First of all I hate those moronic rappers, who...
# 3               3   test  Not even the Beatles could write songs everyon...
# 4               4   test  Brass pictures (movies is not a fitting word f...
# ...           ...    ...                                                ...
# 99995       99995  train  Delightfully awful! Made by David Giancola, a ...
# 99996       99996  train  Watching Time Chasers, it obvious that it was ...
# 99997       99997  train  At the beginning we can see members of Troma t...
# 99998       99998  train  The movie was incredible, ever since I saw it ...
# 99999       99999  train  TCM came through by acquiring this wonderful, ...
#
#        label         file
# 0        neg      0_2.txt
# 1        neg  10000_4.txt
# 2        neg  10001_1.txt
# 3        neg  10002_3.txt
# 4        neg  10003_3.txt
# ...      ...          ...
# 99995  unsup   9998_0.txt
# 99996  unsup   9999_0.txt
# 99997  unsup    999_0.txt
# 99998  unsup     99_0.txt
# 99999  unsup      9_0.txt
#
# [100000 rows x 5 columns]

# %%
# Removing unnamed column from dataset
full_dataset = full_dataset.iloc[:, 1:]
full_dataset
# Out:
#         type                                             review  label  \
# 0       test  Once again Mr. Costner has dragged out a movie...    neg
# 1       test  This is an example of why the majority of acti...    neg
# 2       test  First of all I hate those moronic rappers, who...    neg
# 3       test  Not even the Beatles could write songs everyon...    neg
# 4       test  Brass pictures (movies is not a fitting word f...    neg
# ...      ...                                                ...    ...
# 99995  train  Delightfully awful! Made by David Giancola, a ...  unsup
# 99996  train  Watching Time Chasers, it obvious that it was ...  unsup
# 99997  train  At the beginning we can see members of Troma t...  unsup
# 99998  train  The movie was incredible, ever since I saw it ...  unsup
# 99999  train  TCM came through by acquiring this wonderful, ...  unsup
#
#               file
# 0          0_2.txt
# 1      10000_4.txt
# 2      10001_1.txt
# 3      10002_3.txt
# 4      10003_3.txt
# ...            ...
# 99995   9998_0.txt
# 99996   9999_0.txt
# 99997    999_0.txt
# 99998     99_0.txt
# 99999      9_0.txt
#
# [100000 rows x 4 columns]

# %%
train_dataset = full_dataset[full_dataset.type == "train"]
test_dataset = full_dataset[full_dataset.type == "test"]

# %%
train_dataset
# Out:
#         type                                             review  label  \
# 25000  train  Story of a man who has unnatural feelings for ...    neg
# 25001  train  Airport '77 starts as a brand new luxury 747 p...    neg
# 25002  train  This film lacked something I couldn't put my f...    neg
# 25003  train  Sorry everyone,,, I know this is supposed to b...    neg
# 25004  train  When I was little my parents took me along to ...    neg
# ...      ...                                                ...    ...
# 99995  train  Delightfully awful! Made by David Giancola, a ...  unsup
# 99996  train  Watching Time Chasers, it obvious that it was ...  unsup
# 99997  train  At the beginning we can see members of Troma t...  unsup
# 99998  train  The movie was incredible, ever since I saw it ...  unsup
# 99999  train  TCM came through by acquiring this wonderful, ...  unsup
#
#               file
# 25000      0_3.txt
# 25001  10000_4.txt
# 25002  10001_4.txt
# 25003  10002_1.txt
# 25004  10003_1.txt
# ...            ...
# 99995   9998_0.txt
# 99996   9999_0.txt
# 99997    999_0.txt
# 99998     99_0.txt
# 99999      9_0.txt
#
# [75000 rows x 4 columns]

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75000 entries, 25000 to 99999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   type    75000 non-null  object
#  1   review  75000 non-null  object
#  2   label   75000 non-null  object
#  3   file    75000 non-null  object
# dtypes: object(4)
# memory usage: 2.9+ MB

# %%
train_dataset.describe()
# Out:
#          type                                             review  label  \
# count   75000                                              75000  75000
# unique      1                                              74057      3
# top     train  How has this piece of crap stayed on TV this l...  unsup
# freq    75000                                                  5  50000
#
#            file
# count     75000
# unique    75000
# top     0_3.txt
# freq          1

# %%
train_dataset.head()
# Out:
#         type                                             review label  \
# 25000  train  Story of a man who has unnatural feelings for ...   neg
# 25001  train  Airport '77 starts as a brand new luxury 747 p...   neg
# 25002  train  This film lacked something I couldn't put my f...   neg
# 25003  train  Sorry everyone,,, I know this is supposed to b...   neg
# 25004  train  When I was little my parents took me along to ...   neg
#
#               file
# 25000      0_3.txt
# 25001  10000_4.txt
# 25002  10001_4.txt
# 25003  10002_1.txt
# 25004  10003_1.txt

# %%
train_dataset.label.value_counts()
# Out:
# unsup    50000
# neg      12500
# pos      12500
# Name: label, dtype: int64

# %%
train_dataset = train_dataset[train_dataset.label != "unsup"]

# %%
train_dataset.label.value_counts()
# Out:
# neg    12500
# pos    12500
# Name: label, dtype: int64

# %%
train_dataset
# Out:
#         type                                             review label  \
# 25000  train  Story of a man who has unnatural feelings for ...   neg
# 25001  train  Airport '77 starts as a brand new luxury 747 p...   neg
# 25002  train  This film lacked something I couldn't put my f...   neg
# 25003  train  Sorry everyone,,, I know this is supposed to b...   neg
# 25004  train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 49995  train  Seeing as the vote average was pretty low, and...   pos
# 49996  train  The plot had some wretched, unbelievable twist...   pos
# 49997  train  I am amazed at how this movie(and most others ...   pos
# 49998  train  A Christmas Together actually came before my t...   pos
# 49999  train  Working-class romantic drama from director Mar...   pos
#
#               file
# 25000      0_3.txt
# 25001  10000_4.txt
# 25002  10001_4.txt
# 25003  10002_1.txt
# 25004  10003_1.txt
# ...            ...
# 49995   9998_9.txt
# 49996   9999_8.txt
# 49997   999_10.txt
# 49998     99_8.txt
# 49999      9_7.txt
#
# [25000 rows x 4 columns]

# %%
train_dataset.reset_index(drop=True, inplace=True)

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file
# 0          0_3.txt
# 1      10000_4.txt
# 2      10001_4.txt
# 3      10002_1.txt
# 4      10003_1.txt
# ...            ...
# 24995   9998_9.txt
# 24996   9999_8.txt
# 24997   999_10.txt
# 24998     99_8.txt
# 24999      9_7.txt
#
# [25000 rows x 4 columns]

# %%
train_dataset["Sentiment"] = np.where(train_dataset["label"] == "pos", 1, 0)

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment
# 0          0_3.txt          0
# 1      10000_4.txt          0
# 2      10001_4.txt          0
# 3      10002_1.txt          0
# 4      10003_1.txt          0
# ...            ...        ...
# 24995   9998_9.txt          1
# 24996   9999_8.txt          1
# 24997   999_10.txt          1
# 24998     99_8.txt          1
# 24999      9_7.txt          1
#
# [25000 rows x 5 columns]

# %%
train_dataset["Sentiment_2"] = [1 if i == "pos" else 0 for i in train_dataset.label]

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment  Sentiment_2
# 0          0_3.txt          0            0
# 1      10000_4.txt          0            0
# 2      10001_4.txt          0            0
# 3      10002_1.txt          0            0
# 4      10003_1.txt          0            0
# ...            ...        ...          ...
# 24995   9998_9.txt          1            1
# 24996   9999_8.txt          1            1
# 24997   999_10.txt          1            1
# 24998     99_8.txt          1            1
# 24999      9_7.txt          1            1
#
# [25000 rows x 6 columns]

# %%
def get_sentiment(label):
    if label == "pos":
        return 1
    else:
        return 0

# %%
train_dataset["Sentiment_3"] = train_dataset.label.apply(get_sentiment)

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment  Sentiment_2  Sentiment_3
# 0          0_3.txt          0            0            0
# 1      10000_4.txt          0            0            0
# 2      10001_4.txt          0            0            0
# 3      10002_1.txt          0            0            0
# 4      10003_1.txt          0            0            0
# ...            ...        ...          ...          ...
# 24995   9998_9.txt          1            1            1
# 24996   9999_8.txt          1            1            1
# 24997   999_10.txt          1            1            1
# 24998     99_8.txt          1            1            1
# 24999      9_7.txt          1            1            1
#
# [25000 rows x 7 columns]

# %%
train_dataset["Sentiment_4"] = train_dataset.label.map({"pos": 1, "neg":0})

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment  Sentiment_2  Sentiment_3  Sentiment_4
# 0          0_3.txt          0            0            0            0
# 1      10000_4.txt          0            0            0            0
# 2      10001_4.txt          0            0            0            0
# 3      10002_1.txt          0            0            0            0
# 4      10003_1.txt          0            0            0            0
# ...            ...        ...          ...          ...          ...
# 24995   9998_9.txt          1            1            1            1
# 24996   9999_8.txt          1            1            1            1
# 24997   999_10.txt          1            1            1            1
# 24998     99_8.txt          1            1            1            1
# 24999      9_7.txt          1            1            1            1
#
# [25000 rows x 8 columns]

# %% [markdown]
# # Data Preprocessing
# - Cleaning
# - Tokenization
# - Stop Words Removal
# - Lemmatization
# - Stemming
# - Byte Pair Encoding

# %% [markdown]
# ## Cleaning
# - Removing punctuation symbols
# - Converting it to lower case
# - Removing numbers

# %%
import re
def remove_punctuation(review):
    return re.sub(r'[^\w\s]', "", review)

# %%
train_dataset["review_processed"] = train_dataset.review.apply(remove_punctuation)

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment  Sentiment_2  Sentiment_3  Sentiment_4  \
# 0          0_3.txt          0            0            0            0
# 1      10000_4.txt          0            0            0            0
# 2      10001_4.txt          0            0            0            0
# 3      10002_1.txt          0            0            0            0
# 4      10003_1.txt          0            0            0            0
# ...            ...        ...          ...          ...          ...
# 24995   9998_9.txt          1            1            1            1
# 24996   9999_8.txt          1            1            1            1
# 24997   999_10.txt          1            1            1            1
# 24998     99_8.txt          1            1            1            1
# 24999      9_7.txt          1            1            1            1
#
#                                         review_processed
# 0      Story of a man who has unnatural feelings for ...
# 1      Airport 77 starts as a brand new luxury 747 pl...
# 2      This film lacked something I couldnt put my fi...
# 3      Sorry everyone I know this is supposed to be a...
# 4      When I was little my parents took me along to ...
# ...                                                  ...
# 24995  Seeing as the vote average was pretty low and ...
# 24996  The plot had some wretched unbelievable twists...
# 24997  I am amazed at how this movieand most others h...
# 24998  A Christmas Together actually came before my t...
# 24999  Workingclass romantic drama from director Mart...
#
# [25000 rows x 9 columns]

# %%
def convert_to_lowercase(review):
    return review.lower()

# %%
train_dataset["review_processed"] = train_dataset.review_processed.apply(convert_to_lowercase)

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment  Sentiment_2  Sentiment_3  Sentiment_4  \
# 0          0_3.txt          0            0            0            0
# 1      10000_4.txt          0            0            0            0
# 2      10001_4.txt          0            0            0            0
# 3      10002_1.txt          0            0            0            0
# 4      10003_1.txt          0            0            0            0
# ...            ...        ...          ...          ...          ...
# 24995   9998_9.txt          1            1            1            1
# 24996   9999_8.txt          1            1            1            1
# 24997   999_10.txt          1            1            1            1
# 24998     99_8.txt          1            1            1            1
# 24999      9_7.txt          1            1            1            1
#
#                                         review_processed
# 0      story of a man who has unnatural feelings for ...
# 1      airport 77 starts as a brand new luxury 747 pl...
# 2      this film lacked something i couldnt put my fi...
# 3      sorry everyone i know this is supposed to be a...
# 4      when i was little my parents took me along to ...
# ...                                                  ...
# 24995  seeing as the vote average was pretty low and ...
# 24996  the plot had some wretched unbelievable twists...
# 24997  i am amazed at how this movieand most others h...
# 24998  a christmas together actually came before my t...
# 24999  workingclass romantic drama from director mart...
#
# [25000 rows x 9 columns]

# %%
def remove_numbers(review):
    return re.sub(r'[\d+]', "", review)

# %%
train_dataset["review_processed"] = train_dataset.review_processed.apply(remove_numbers)

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment  Sentiment_2  Sentiment_3  Sentiment_4  \
# 0          0_3.txt          0            0            0            0
# 1      10000_4.txt          0            0            0            0
# 2      10001_4.txt          0            0            0            0
# 3      10002_1.txt          0            0            0            0
# 4      10003_1.txt          0            0            0            0
# ...            ...        ...          ...          ...          ...
# 24995   9998_9.txt          1            1            1            1
# 24996   9999_8.txt          1            1            1            1
# 24997   999_10.txt          1            1            1            1
# 24998     99_8.txt          1            1            1            1
# 24999      9_7.txt          1            1            1            1
#
#                                         review_processed
# 0      story of a man who has unnatural feelings for ...
# 1      airport  starts as a brand new luxury  plane i...
# 2      this film lacked something i couldnt put my fi...
# 3      sorry everyone i know this is supposed to be a...
# 4      when i was little my parents took me along to ...
# ...                                                  ...
# 24995  seeing as the vote average was pretty low and ...
# 24996  the plot had some wretched unbelievable twists...
# 24997  i am amazed at how this movieand most others h...
# 24998  a christmas together actually came before my t...
# 24999  workingclass romantic drama from director mart...
#
# [25000 rows x 9 columns]

# %% [markdown]
# ## Tokenization and Stopwords Removal

# %%
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/niketan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function that does tokenization
def tokenize_words(review):
    tokenizer = ToktokTokenizer()
    tokens = tokenizer.tokenize(review)
    tokens = [token.strip() for token in tokens]
    return " ".join(tokens)

# %%
stopwords_list = stopwords.words("english")
def apply_tokenization_and_remove_stopwords(review):
    # Applying tokenization
    tokenizer = ToktokTokenizer()
    tokens = tokenizer.tokenize(review)
    tokens = [token.strip() for token in tokens]
    # applying removal of stopwords
    review_no_stopwords = [word for word in tokens if word not in stopwords_list]
    return " ".join(review_no_stopwords)

# %%
train_dataset["review_processed"] = train_dataset.review_processed.apply(apply_tokenization_and_remove_stopwords)

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment  Sentiment_2  Sentiment_3  Sentiment_4  \
# 0          0_3.txt          0            0            0            0
# 1      10000_4.txt          0            0            0            0
# 2      10001_4.txt          0            0            0            0
# 3      10002_1.txt          0            0            0            0
# 4      10003_1.txt          0            0            0            0
# ...            ...        ...          ...          ...          ...
# 24995   9998_9.txt          1            1            1            1
# 24996   9999_8.txt          1            1            1            1
# 24997   999_10.txt          1            1            1            1
# 24998     99_8.txt          1            1            1            1
# 24999      9_7.txt          1            1            1            1
#
#                                         review_processed
# 0      story man unnatural feelings pig starts openin...
# 1      airport starts brand new luxury plane loaded v...
# 2      film lacked something couldnt put finger first...
# 3      sorry everyone know supposed art film wow hand...
# 4      little parents took along theater see interior...
# ...                                                  ...
# 24995  seeing vote average pretty low fact clerk vide...
# 24996  plot wretched unbelievable twists however chem...
# 24997  amazed movieand others average stars lower cra...
# 24998  christmas together actually came time ive rais...
# 24999  workingclass romantic drama director martin ri...
#
# [25000 rows x 9 columns]

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
def apply_lemmatization(review):
    lemmatized_review = []
    lemmatizer = WordNetLemmatizer()
    tokenizer = ToktokTokenizer()
    tokens = tokenizer.tokenize(review)
    tokens = [token.strip() for token in tokens]
    for w in tokens:
        lemmatized_review.append(lemmatizer.lemmatize(w))
    return " ".join(lemmatized_review)
# Out:
# [nltk_data] Downloading package wordnet to /Users/niketan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/niketan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
s = "Story of a man who has unnatural instincts"
apply_lemmatization(s)
# Out:
# 'Story of a man who ha unnatural instinct'

# %%
train_dataset["review_processed"] = train_dataset.review_processed.apply(apply_lemmatization)

# %%
train_dataset
# Out:
#         type                                             review label  \
# 0      train  Story of a man who has unnatural feelings for ...   neg
# 1      train  Airport '77 starts as a brand new luxury 747 p...   neg
# 2      train  This film lacked something I couldn't put my f...   neg
# 3      train  Sorry everyone,,, I know this is supposed to b...   neg
# 4      train  When I was little my parents took me along to ...   neg
# ...      ...                                                ...   ...
# 24995  train  Seeing as the vote average was pretty low, and...   pos
# 24996  train  The plot had some wretched, unbelievable twist...   pos
# 24997  train  I am amazed at how this movie(and most others ...   pos
# 24998  train  A Christmas Together actually came before my t...   pos
# 24999  train  Working-class romantic drama from director Mar...   pos
#
#               file  Sentiment  Sentiment_2  Sentiment_3  Sentiment_4  \
# 0          0_3.txt          0            0            0            0
# 1      10000_4.txt          0            0            0            0
# 2      10001_4.txt          0            0            0            0
# 3      10002_1.txt          0            0            0            0
# 4      10003_1.txt          0            0            0            0
# ...            ...        ...          ...          ...          ...
# 24995   9998_9.txt          1            1            1            1
# 24996   9999_8.txt          1            1            1            1
# 24997   999_10.txt          1            1            1            1
# 24998     99_8.txt          1            1            1            1
# 24999      9_7.txt          1            1            1            1
#
#                                         review_processed
# 0      story man unnatural feeling pig start opening ...
# 1      airport start brand new luxury plane loaded va...
# 2      film lacked something couldnt put finger first...
# 3      sorry everyone know supposed art film wow hand...
# 4      little parent took along theater see interior ...
# ...                                                  ...
# 24995  seeing vote average pretty low fact clerk vide...
# 24996  plot wretched unbelievable twist however chemi...
# 24997  amazed movieand others average star lower crap...
# 24998  christmas together actually came time ive rais...
# 24999  workingclass romantic drama director martin ri...
#
# [25000 rows x 9 columns]
